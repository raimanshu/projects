# %% [markdown]
# - Problem Statement
# - Docker
# - Docker CLI
#     - Docker Version
#         docker --version
# - Docker Desktop
# - Docker Daemon
# - Docker Registry / Docker Hub
# - Container
# - Image
# - Handling Multiple Containers
# - Port Mapping
#     docker run -p 8080:8080 <image_name>
# - Passing Environment Variables
#     docker run -e <key>=<value> -e <key>=<value> <image_name>
# - Create an Image
#     - Dockerfile
#         - FROM <image_name>
#         - RUN <command>
#         - WORKDIR <path>
#         - COPY <file_name> <destination_path>
#         - CMD <command>
#         - ENTRYPOINT <command>
#     - .dockerignore
#     - Building Docker Image
#         docker build -t <image_name> <path_to_dockerfile>
#     - Caching Layers
#     - Multi-Stage Build
#     - Publishing Image on Hub
#         docker push <image_name>
# - Docker Compose
#     - docker-compose.yml
#         - version: '3.8'
#         - services:
#             <service_name>:
#                 image: <image_name>
#                 ports:
#                     <port_number>:<port_number>
#                 environment:
#                     <key>=<value>
#                     <key>=<value>
#                 volumes:
#                     <path_to_file>:<path_to_file>
#     - Running Docker Compose
#         - docker-compose up
#     - Running Docker Compose in Background
#         - docker-compose up -d
#     - Stopping Docker Compose
#         - docker-compose down
# - Docker Network
#     - Types of Networks
#         - Bridge (Default)
#         - Host
#         - None
#         - Overlay
#         - Macvlan
#     - Inspecting Networks
#         - docker network inspect <network_name>
#     - List Networks
#         - docker network ls
#     - Creating a Network
#         - docker network create <network_name>
#         - docker network create --driver <driver_name> <network_name>
# - Docker Volumes
#     - Volume Mounting
#       - docker run -v <path_to_file>:<path_to_file> <image_name>
#     - Types of Volumes
#     - Bind Mounts
#         - Named Volumes
#         - Anonymous Volumes
# - AWS ECS (Elastic Container Service)
