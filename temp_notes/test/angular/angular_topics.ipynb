# %% [markdown]
# Angular
#     - Single Page Application (SPA)
#     - MVC Achitecture
#     - Angular vs React
#     - Setup and Installation
#     - Folder and File Structure
#         - package.json
#         - package-lock.json
#         - tsconfig.json
#         - tsconfig.app.json
#         - tsconfig.spec.json
#         - angular.json
#         - .browserslistrc
#         - .editorconfig
#         - node_modules/
#         - src/
#             - app/
#             - index.html
#             - main.ts
#             - polyfills.ts
#             - styles.css
#         - public/
# - Angular CLI
#     - ng new
# - Data Binding
#     - Interpolation
#     - Property Binding
#     - Event Binding
#     - Two Way Binding
# - Components
#     - Component Decorator / @Component({...})
#     - Selector
#     - templateUrl
#     - styleUrls
#     - template
#     - styles
#     - Property Name vs Variable Name
# - Event Handling
#     - $event
#     - Template Reference Variable
# - Style Options
#     - Styles in component file
#     - Global Styles
#     - Styles in html file using tag
#     - Styles in html file using style attribute
#     - Styles in html file using class attribute
#     - Styles in html file using ngClass
#     - Styles from multiple files
# - Cinditional Rendering
#     - *ngIf
#     - @if(condition){...}
#     - *ngIf else
#     - @if(condition){...}else{...}
#     - ngSwitch, *ngSwitchCase, *ngSwitchDefault
#     - @switch(condition){ @case(value){...} @default{...} }
#     - ng-content
#     - ng-container
#     - ng-template
#     - ng-template-outlet
#     - @defer(on viewport){...}placeholder{...}
# - Looping
#     - *ngFor
#     - @for(item of items; track: item.id ){...}
#     - @for(item of items; track: item.id ){...}@empty{...}
#     - Contextual Variables
#         - $index
#         - $even
#         - $odd
#         - $first
#         - $last
#         - $count
# - Signals
#     - get Signals
#     - set Signals
#     - Types of Signals
#       - Writable Signals
#       - Computed Signals or Readonly Signals
#     - effect(() => {})
# - Directives
#     - Types of Directives
#         - Component Directives
#         - Structural Directives
#         - Attribute Directives
# - Routing/Navigation
#     - RouterModule
#     - RouterLink
#     - RouterLinkActive
#     - RouterLinkActiveOption
#     - RouterOutlet
#     - Wildcard Route
#     - Passing Data using Route
#         - With RouterLink
#         - With Button Click
#         - With Router
#         - ActivatedRoute
#     - Dynamic Routing
#     - AuthGuard
#     - Types of AuthGuard
#         - CanActivate
#         - CanActivateChild
#         - CanDeactivate
#         - CanLoad
#     - Phases of Navigation
# - Forms
#     - Template Driven Forms
#         - FormsModule
#         - ngModel
#         - ngModelGroup
#         - ngForm
#     - Reactive Forms
#       - ReactiveFormsModule
#       - FormControl
#       - FormGroup
#       - FormBuilder
#       - FormArray
#       - Validators
#       - Custom Validators
#     - ngSubmit
#     - get Form Values
#     - set Form Values
#     - invalid vs valid
#     - pristine vs dirty
#     - touched vs untouched
# - Passing Data between Components
#     - Parent To Child
#         - @Input()
#         - Alisas
#         - @ViewChild()
#     - Child To Parent
#         - @Output()
#         - Aliases
#         - EventEmitter
# - Pipies
#     - Built-in Pipes
#     - Pipes Chaining
#     - Pipes with Arguments
#     - Custom Pipes
#         - PipeTransform
# - Component Lifecycle Hooks
#     - ngOnChanges
#     - ngOnInit
#     - ngDoCheck
#     - ngAfterContentInit
#     - ngAfterContentChecked
#     - ngAfterViewInit
#     - ngAfterViewChecked
#     - ngAfterNextRender
#     - ngAfterRender
#     - ngOnDestroy
# - Services
#     - @Injectable
#     - @Inject
#     - new syntax initialization vs old syntax initialization
#     - Interfaces
#     - HttpClient
#     - HttpClientModule
#     - provideHttpClient
#     - subscribe()
#     - Interceptors
#     - Observables
#       - Subject
#       - BehaviorSubject
#       - ReplaySubject
#       - AsyncSubject
#     - RxJS
#     - RxJS vs Peomises vs async/await
#     - RxJS Operators
# - json-server
# - Lazy Loading
#     - loadComponent()
#     - loadChildren()
# - Server Side Rendering (SSR)
#     - Angular Universal
#     - Prerendering (SSG)
#     - Hydration
# - Project Modulization
#     - Standalone Project
#     - Using NgModule
# - ZoneJS
# - @let
# - NgRx
#     - Store
# - Internationalization (i18n)
# - Localization (l10n)
# - Angular Architectures
#     - Angular Elements
#     - Decorators
#     - Angular Bootstrapping
#     - Angular Compiler
#       - Just In Time (JIT)
#       - Ahead Of Time (AOT)
#     - Bunding
# - Testing
